# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920x1080")
options.add_argument("--lang=ko_KR")
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
options.add_argument(f"--user-agent={user_agent}")

driver = webdriver.Chrome(service = service, options = options)
url = "ㅠkr/"
driver.get(url)
time.sleep(2)

for _ in range(10) :
    title_btn = driver.find_element(By.CSS_SELECTOR, "button.btn_scroll.btn_brunch.btn_next")
    title_btn.click()
    time.sleep(2)

    titles = driver.find_elements(By.XPATH, "//a[@data-tiara-copy]")
    for title in titles : 
        print(title.text.strip().replace("\n", ""))   

driver.quit()
# Out:
# 주목받고 있는 응원 인기글을소개합니다.Ella Song쿠마라응원 뱃지
# 요만큼의한국사시즌2goeunpabrunch bookFirst EditionReleased date.Oct 24, 2024
# 천방지축 어리둥절빙글빙글 돌아가는신입 사서의 하루by 예안
# 오늘 간식 뭐드실래요(4)사무실 간식 ...by 늘여름
# 넘치는 이름값,뉴욕 베이글파리 하면 "바게트" (또는"크루아상"), 런던 하면 "스...by성급한뭉클쟁이
# 늙은 부모의 가난은슬프다.부모님의 가난만큼 안타까운 것이없는데, 그들이 주는 사랑은 한...by크런치바
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 천방지축 어리둥절빙글빙글 돌아가는신입 사서의 하루by 예안
# 오늘 간식 뭐드실래요(4)사무실 간식 ...by 늘여름
# 넘치는 이름값,뉴욕 베이글파리 하면 "바게트" (또는"크루아상"), 런던 하면 "스...by성급한뭉클쟁이
# 늙은 부모의 가난은슬프다.부모님의 가난만큼 안타까운 것이없는데, 그들이 주는 사랑은 한...by크런치바
# 에어컨은 시원한데,몸이 시원찮다.3박 4일 여행을 마치고 집으로돌아오는 길. 차 안은 에어컨이...bySusie 방글이
# 내게 운동복이하나도 없는 이유by두어썸머
#
# 어느 관제사의 하루by동경
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 늙은 부모의 가난은슬프다.부모님의 가난만큼 안타까운 것이없는데, 그들이 주는 사랑은 한...크런치바
# 에어컨은 시원한데,몸이 시원찮다.3박 4일 여행을 마치고 집으로돌아오는 길. 차 안은 에어컨이...bySusie 방글이
# 내게 운동복이하나도 없는 이유by두어썸머
# 난 정말 무리하지않았다by엄마의 왈츠
# 어느 관제사의 하루by동경
# 교사, 세 개의자아by둥리지
# 한국인은 한국인내가 처음 캐나다에 도착해서 느낀감정은 ‘이질감’이었다. 나는 ...bynormal B
#
#
#
#
#
#
#
#
#
# ...

# %%
https://scholar.google.com/scholar?hl=ko&as_sdt=0%2C5&q=SEO+marketing&btnG=
