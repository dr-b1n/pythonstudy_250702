# %% [markdown]
# ##### 1. 네이버 뉴스에서 "디지털 마케팅" 키워드로 검색한 뉴스 제목 10개를 수집하세요

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

# 1. 옵션에 대한 설정
options = Options()
options.add_argument("--disable-gpu")
options.add_argument("--start-maximized")
options.add_argument("--headless")

# 2. 드라이버 설정
service = Service("C:\\Users\\user\\Downloads\\chromedriver\\chromedriver.exe")
url = "https://search.naver.com/search.naver?ssc=tab.news.all&where=news&sm=tab_jum&query=%EB%94%94%EC%A7%80%ED%84%B8+%EB%A7%88%EC%BC%80%ED%8C%85"
driver = webdriver.Chrome(service = service, options = options)
driver.get(url)

headlines = driver.find_elements(By.XPATH, "//span[@class = 'sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-headline1']")

for idx, headline in enumerate(headlines[:10]):
    print(idx+1, headline.text)
# Out:
# 1 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공동 공략
# 2 JT저축은행-한국폴리텍대학, 디지털 역량 강화 위한 챗GPT 교육
# 3 조선대, 인도네시아 에어랑가대학 대상 치과기술 마케팅 연수 개최
# 4 SOOP, 2Q 영업익 300억·9.9%↓…'마케팅·인건비' 상승 영향
# 5 롯데·신라免, 타겟 마케팅으로 부진 속 돌파구 찾는다
# 6 국민체육진흥공단, '전국 대학생 스포츠 마케팅 경진 대회' 개최
# 7 진화하는 은행 캐릭터 마케팅…신한은행 "금융 여정 동행 경험 심는다"
# 8 다날·한컴위드, 스테이블코인 전자금융 사업 본격화 …"시장 최적화 디...
# 9 [Biz-inside,China] 쑥쑥 크는 中 전자상거래, AI로 무장하다…상담·마케...
# 10 정읍시, 지황 농산물 가공식품 온라인 마케팅 강화교육 수료

# %%
## 정답

import requests
from bs4 import BeautifulSoup

query = "디지털 마케팅"
url = f"https://search.naver.com/search.naver?where=news&query={query}"

headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("a.ox1N67gcMkHhMh7hbfHi.VZxw34rcBHTWHgERxv0b")

for i, title in enumerate(titles[:10], 1)  :
    print(f"{i}. {title.text.strip()}")
# Out:
# 1. 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공동 공략
# 2. JT저축은행-한국폴리텍대학, 디지털 역량 강화 위한 챗GPT 교육
# 3. 조선대, 인도네시아 에어랑가대학 대상 치과기술 마케팅 연수 개최
# 4. SOOP, 2Q 영업익 300억·9.9%↓…'마케팅·인건비' 상승 영향
# 5. 롯데·신라免, 타겟 마케팅으로 부진 속 돌파구 찾는다
# 6. 국민체육진흥공단, '전국 대학생 스포츠 마케팅 경진 대회' 개최
# 7. 진화하는 은행 캐릭터 마케팅…신한은행 "금융 여정 동행 경험 심는다"
# 8. 다날·한컴위드, 스테이블코인 전자금융 사업 본격화 …"시장 최적화 디...
# 9. [Biz-inside,China] 쑥쑥 크는 中 전자상거래, AI로 무장하다…상담·마케...
# 10. 정읍시, 지황 농산물 가공식품 온라인 마케팅 강화교육 수료

# %% [markdown]
# ##### 2. 다음 뉴스에서 IT 섹션의 기사 제목과 링크를 수집하세요

# %%
import requests
from bs4 import BeautifulSoup


url = "https://news.daum.net/tech"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("div>strong.tit_txt")
links = soup.select("li>a.href")

for idx, title in enumerate(titles) :
    for link in links :
        print(idx+1, title.get_text())
        print(link)

# %%
## 정답

import requests
from bs4 import BeautifulSoup

url = "https://news.daum.net/tech"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

articles = soup.select("ul.list_newsheadline2 li a.item_newsheadline2")

for i, article in enumerate(articles, 1) :
    title = article.text.strip()
    link = article["href"]
    print(f"{i}. {title} - {link}")
# Out:
# 1. 수천만 개 사내문서도 ‘뚝딱’…日서 난리 난 AI가 국내산? '시간이 없는데 언제 일일히 사내 문서를 찾아보지.' 이 같이 대다수 직장인들이 하는 업무의 비효율성 문제를 해결한 기업이 있다. 코딩 없이 AI를 활용할 수 있게 만든 ‘노코드 AI 플랫폼’을 전면에 앞세우면서다. 이 기업은 자체 기술로 일본 기업용 AI 시장을 단숨에 장악하고 있다. 엔터프라이즈 특화 생성형 AI 솔루션 기업 올거나이즈는 자사의 LLM 한국경제 2분 전 - https://v.daum.net/v/20250730141204652
# 2. 하반기 줄잇는 신작게임에 'MMORPG' 부활…"사활 걸었다" 머니투데이 3분 전 - https://v.daum.net/v/20250730141146624
# 3. 뜨거운 감자 '게임 질병코드'… 문체-복지, 엇갈린 답변에 대립각 재점화 전자신문 3분 전 - https://v.daum.net/v/20250730141104596
# 4. AI로 디지털 자신감 키운다…과학동아AiR 수업에서 몰입 효과 확인 동아사이언스 6분 전 - https://v.daum.net/v/20250730140804479
# 5. 네이처 “中 인재 유치 정책, 연구 능력 높였지만 내부 균열도 심화” 조선비즈 11분 전 - https://v.daum.net/v/20250730140257231
# 6. 폭염·열대야에도 생체 시계 고장 없는 이유…[달콤한 사이언스] 서울신문 12분 전 - https://v.daum.net/v/20250730140204159
# 7. [人사이트] 전명준 KT 데이터서비스담당 “디도스 공격 대형화 추세…클린존으로 기업 보안관될 것” 전자신문 21분 전 - https://v.daum.net/v/20250730135300778
# 8. 냅킨에 적은 아이디어가 5년 뒤 논문으로…"수학연구의 시작은 대화" 동아사이언스 27분 전 - https://v.daum.net/v/20250730134747596
# ...

# %% [markdown]
# ##### 3. yes24 경제 베스트셀러 1~10위 도서 제목과 저자를 수집하세요

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.yes24.com/Product/Category/Display/001001025"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

bests = soup.select("div>a.gd_name")
authors = soup.select("span.auth")

for best in bests :
    for i, author in enumerate (authors[:10],1) :
        name = best.text.strip()
        authorr = author.get_text()
        print(f"{i}.{name} - {authorr}")
# Out:
# 1.새로운 질서 - 헨리 키신저,에릭 슈밋,크레이그 먼디 저/이현 역
# 2.새로운 질서 - 네이트 실버Nate Silver 저/김고명 역
# 3.새로운 질서 - 박종훈 저
# 4.새로운 질서 - 박곰희 저
# 5.새로운 질서 - 레이 달리오 저/조용빈 역
# 6.새로운 질서 - 스티븐 위트 저/백우진 역
# 7.새로운 질서 - 박곰희 저
# 8.새로운 질서 - 잼투리 저
# 9.새로운 질서 - 메리츠증권 리서치센터 저
# 10.새로운 질서 - 이정윤 저
# 1.리스크테이커 - 헨리 키신저,에릭 슈밋,크레이그 먼디 저/이현 역
# 2.리스크테이커 - 네이트 실버Nate Silver 저/김고명 역
# 3.리스크테이커 - 박종훈 저
# 4.리스크테이커 - 박곰희 저
# 5.리스크테이커 - 레이 달리오 저/조용빈 역
# 6.리스크테이커 - 스티븐 위트 저/백우진 역
# 7.리스크테이커 - 박곰희 저
# 8.리스크테이커 - 잼투리 저
# 9.리스크테이커 - 메리츠증권 리서치센터 저
# 10.리스크테이커 - 이정윤 저
# 1.세계 경제 지각 변동 - 헨리 키신저,에릭 슈밋,크레이그 먼디 저/이현 역
# 2.세계 경제 지각 변동 - 네이트 실버Nate Silver 저/김고명 역
# 3.세계 경제 지각 변동 - 박종훈 저
# 4.세계 경제 지각 변동 - 박곰희 저
# 5.세계 경제 지각 변동 - 레이 달리오 저/조용빈 역
# 6.세계 경제 지각 변동 - 스티븐 위트 저/백우진 역
# 7.세계 경제 지각 변동 - 박곰희 저
# 8.세계 경제 지각 변동 - 잼투리 저
# 9.세계 경제 지각 변동 - 메리츠증권 리서치센터 저
# 10.세계 경제 지각 변동 - 이정윤 저
# 1.박곰희 연금 부자 수업 - 헨리 키신저,에릭 슈밋,크레이그 먼디 저/이현 역
# 2.박곰희 연금 부자 수업 - 네이트 실버Nate Silver 저/김고명 역
# 3.박곰희 연금 부자 수업 - 박종훈 저
# 4.박곰희 연금 부자 수업 - 박곰희 저
# ...

# %%
## 정답

import requests
from bs4 import BeautifulSoup

url = "https://www.yes24.com/product/category/steadyseller?pageNumber=1&pageSize=24&categoryNumber=001001025007"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

books = soup.select("ul#yesBestList > li")

for i, book in enumerate(books[:10], 1) :
    title_tag = book.select_one("div.info_row.info_name a.gd_name")
    author_tag = book.select_one("span.authPub.info_auth")

    if title_tag and author_tag :
        title = title_tag.text.strip()
        author = author_tag.text.strip()
        print(f"{i}. {title}-{author}")
# Out:
# 1. 자본주의-EBS 〈자본주의〉제작팀, 정지은, 고희정 저/EBS MEDIA 기획
# 2. 생각에 관한 생각-대니얼 카너먼 저/이창신 역
# 3. 더 그레이트 비트코인-오태민 저
# 4. 부의 추월차선 (10주년 스페셜 에디션)-엠제이 드마코 저/신소영 역
# 5. 레버리지-롭 무어 저/김유미 역
# 6. 달러는 왜 비트코인을 싫어하는가-사이페딘 아모스 저/위대선 역
# 7. 넛지: 파이널 에디션-리처드 탈러, 캐스 선스타인 저/이경식 역/최정규 감수
# 8. 시대예보: 핵개인의 시대-송길영 저
# 9. 일할 사람이 사라진다-이철희 저
# 10. 경제신문이 말하지 않는 경제 이야기-임주영 저

# %% [markdown]
# ##### 4. 기상청 날씨 페이지에서 오늘의 전국 날씨 요약을 추출하세요.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.weather.go.kr/w/weather/forecast/short-term.do#dong/1165052000/37.4931456/127.025152/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EC%84%9C%EC%B4%88%EA%B5%AC%20%EC%84%9C%EC%B4%882%EB%8F%99/LOC/%EC%9C%84%EA%B2%BD%EB%8F%84(37.49,127.03)"
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
response.encoding = "utf-8"

soup = BeautifulSoup(response.text, "html.parser")

weatherInfo = soup.select("div.cmp-view-content> p.summary")
for weather in weatherInfo :
    print(weather.get_text().strip().strip().replace("\n", ""))
# Out:
# □  (종합) 당분간 무더위와 열대야 주의, 전남해안과 경남남해안, 제주도해안 너울 유의○  (오늘, 30일) 전국 대체로 맑겠으나, 서쪽 지역부터 차차 구름많아짐,                  오후(12~18시)부터 저녁(18~21시) 사이 인천.경기북부와 강원중.북부내륙.산지 곳에 따라 소나기,                  밤(18~24시)까지 제주도산지 0.1mm 미만 빗방울      ○  (내일, 31일) 남부지방 대체로 맑겠으나, 중부지방과 제주도 구름많음               ○  (모레~글피, 8월 1~2일) 전국 가끔 구름많겠으나, 제주도 대체로 흐림            *  소나기에 의한 예상 강수량(30일)-  (수도권) 인천.경기북부: 5~30mm-  (강원도) 강원중.북부내륙.산지: 5~30mm

# %%
## 정답
import requests
from bs4 import BeautifulSoup

url = "https://www.weather.go.kr/w/weather/forecast/short-term.do"
headers  = {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
response.encoding = "utf-8"

soup = BeautifulSoup(response.text, "html.parser")

summary_tag = soup.select_one("div.cmp-view-content > p.summary > span.depth_1")

if summary_tag :
    print("오늘의 전국 날씨 요약 :")
    print(summary_tag.text.strip())

else :
    print("날씨 요약 정보를 찾을 수 없습니다")
# Out:
# 오늘의 전국 날씨 요약 :
# □  (종합) 당분간 무더위와 열대야 주의, 전남해안과 경남남해안, 제주도해안 너울 유의

# %% [markdown]
# ##### 5. 잡코리아에서 "데이터 분석가" 직무 공고 제목 20개를 수집하세요

# %%
import requests
from bs4 import BeautifulSoup

stext = "데이터 분석가"
url = f"https://www.jobkorea.co.kr/Search/?stext={stext}"

headers  = {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
response.encoding = "utf-8"

soup = BeautifulSoup(response.text, "html.parser")

jtitles = soup.select("span.Typography_variant_size18__344nw25.Typography_weight_medium__344nw2c.Typography_color_gray800__344nw2l")

for i, jtitle in enumerate (jtitles[:20], 1) :
    print(f"{i}. {jtitle.get_text()}")
# Out:
# 1. 데이터 분석가 (경력)
# 2. 데이터 분석가
# 3. [CVS] 데이터 분석가(Business Analyst)
# 4. [쿡앱스] 게임 데이터 분석가 모집
# 5. [기어세컨드] 데이터 분석가 채용
# 6. 데이터 애널리스트 / 데이터분석 전문가 / 통계 전문가 / Data Analyst (통
# 7. Data Analyst (데이터 분석가)
# 8. [CVS] 데이터 분석가 1년 인턴 (Business Analyst Intern)
# 9. [인텔리전스랩스그룹] 데이터 분석가 (인게임 로그 및 비즈니스 인사이트 분석)
# 10. 공공데이터 품질 관리와 진단, 데이터 분석가
# 11. 데이터 분석가(신입/경력)
# 12. [다우키움 계열사] 데이터 분석가 (경력)
# 13. [통계팀] 데이터 분석가 모집
# 14. [커머스플랫폼팀] 데이터 분석 전문가 (Senior Data Analyst) 모집
# 15. [디저트39] 데이터 분석가(Data Analyst)/데이터 분석 엔지니어 팀장급
# 16. 데이터분석가 구인
# 17. [어니컴(주)] 데이터분석가 신입/경력 모집
# 18. [(중급이상/ 경력직)] 빅데이터 전문가를 모십니다
# 19. 데이터분석가 채용(경력)
# 20. [리비바이오] 데이터분석가

# %%
##### 정답 

import requests
from bs4 import BeautifulSoup

query = "데이터 분석가"
url = f"https://www.jobkorea.co.kr/Search/?stext={query}"

headers  = {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("div.styles_mb_space8__dk46ts1p a.sn28bt0")

for i, title_tag in enumerate(titles[:20], 1) :
    print(f"{i}. {title_tag.text.strip()}")
# Out:
# 1. 데이터 분석가 (경력)
# 2. 데이터 분석가
# 3. [CVS] 데이터 분석가(Business Analyst)
# 4. [쿡앱스] 게임 데이터 분석가 모집
# 5. [기어세컨드] 데이터 분석가 채용
# 6. 데이터 애널리스트 / 데이터분석 전문가 / 통계 전문가 / Data Analyst (통
# 7. Data Analyst (데이터 분석가)
# 8. [CVS] 데이터 분석가 1년 인턴 (Business Analyst Intern)
# 9. [인텔리전스랩스그룹] 데이터 분석가 (인게임 로그 및 비즈니스 인사이트 분석)
# 10. 공공데이터 품질 관리와 진단, 데이터 분석가
# 11. 데이터 분석가(신입/경력)
# 12. [다우키움 계열사] 데이터 분석가 (경력)
# 13. [통계팀] 데이터 분석가 모집
# 14. [커머스플랫폼팀] 데이터 분석 전문가 (Senior Data Analyst) 모집
# 15. [디저트39] 데이터 분석가(Data Analyst)/데이터 분석 엔지니어 팀장급
# 16. 데이터분석가 구인
# 17. [어니컴(주)] 데이터분석가 신입/경력 모집
# 18. [(중급이상/ 경력직)] 빅데이터 전문가를 모십니다
# 19. 데이터분석가 채용(경력)
# 20. [리비바이오] 데이터분석가

# %% [markdown]
# ##### 6. 잡코리아에서 "데이터 분석가" 직무 공고 제목 20개를 수집하세요
# - selenium으로 크롤링 하기
# - 6개 페이지 크롤링 하기
# - 서울 지역 내 직무 공고 & 경력 1-3년차만 크롤링 해오기
# - 엑셀 출력 (*해당 공고 타이틀과 지원할 수 있는 URL 링크)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from openpyxl import Workbook
import time

# 1. 옵션 설정
options = Options()
service = Service()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-share-usage")

driver = webdriver.Chrome(options = options, service = service)
stext = "데이터 분석가"
careerType = 2
careerMin =1
careerMax =3
url = f"https://www.jobkorea.co.kr/Search/?{stext}&careerType={careerType}&careerMin={careerMin}&careerMax={careerMax}"

driver.get(url)

titles = driver.find_elements(By.XPATH, "//span[@class = 'Typography_variant_size18__344nw25']")
for title in titles :
    print(title.text)

time.sleep(5)
driver.quit()

# %%
## 정답

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
import urllib.parse
import pandas as pd

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "데이터 분석가"
encoded_query = urllib.parse.quote(query)

max_pages = 6

results = []

for page in range(1, max_pages + 1) :
    url = f"https://www.jobkorea.co.kr/Search/?stext={encoded_query}&Page_No={page}&local=I000&tabType=recruit"
    driver.get(url)
    time.sleep(2)

    job_posts = driver.find_elements(By.CSS_SELECTOR, "div.styles_mb_space8__dk46ts1p")
    for post in job_posts :
        try :
            title_elem = post.find_element(By.CSS_SELECTOR, "a.sn28bt0")
            title = title_elem.text.strip()
            link = title_elem.get_attribute("href")
            results.append({
                "제목" : title,
                "지원링크" : link
            })
        except :
            continue
driver.quit()            

df = pd.DataFrame(results)
df.to_excel("잡코리아_데이터분석가_서울_신입_3페이지.xlsx", index=False)
print("엑셀 저장 완료!")
# Out:
# 엑셀 저장 완료!
