# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
## 1. 서비스, 옵션 설정

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--lang=ko_KR")
options.add_argument("--start-maximized")
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
options.add_argument(f"--user-agent={user_agent}")

driver = webdriver.Chrome(service = service, options = options)
url = "https://www.nocutnews.co.kr/news/entertainment"
driver.get(url)
time.sleep(2)

titles = driver.find_elements(By.CSS_SELECTOR, "div.con_col2th strong.clamp2")
for idx, title in enumerate (titles[:10], 1) :
    print (f"{idx}. {title.text.strip()}")  

driver.quit()
# Out:
# 1. 돌아온 '웬즈데이'…총괄 프로듀서·작가가 본 웬즈데이 MBTI는?
# 2. 거미♥조정석 두 아이 부모된다…5년 만에 둘째 임신
# 3. '데뷔 18주년' 앞둔 소녀시대, 티파니 생일→완전체 회동
# 4. '컨저링 유니버스'의 최종장이 온다…'마지막 의식' 9월 개봉
# 5. BTS 뷔, 팬 무질서 소신발언 "공항은 우리 것 아냐"
# 6. 이보영이 던진 '안락사' 화두 "걱정되지만…말할 기회되길"[현장EN:]
# 7. 아이브 시축 의상 "TPO 맞지 않아" 비판…코디에 멤버 대상 악플까지
# 8. 주디와 닉의 빛나는 팀워크가 돌아온다…'주토피아 2' 예고 공개
# 9. 줄리엔 강, 장모 갈등 해명 "방송은 짧은 단면…오해 그만"
# 10. '발레리나'→BTS 진 솔로 팬콘…롯데시네마 8월 '광음시네마' 라인업

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920x1080")
options.add_argument("--lang=ko_KR")
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
options.add_argument(f"--user-agent={user_agent}")

# 2. 드라이버에 대한 설정
url = "https://www.sooplive.co.kr/live/all"
driver = webdriver.Chrome(service=service, options=options)
driver.get(url)
time.sleep(2)

titles = driver.find_elements(By.CSS_SELECTOR, "h3.title")
for title in titles :
    print(title.text.strip())

driver.quit()
# Out:
# 김민교 LCK 젠지 vs KT #LckWatchParty
# 깨박이X이지상 그릴래영 무수택시
# 최가네 하차하는 멤버 드릴말씀있습니다
# [GEN vs KT] 2025 LCK
# 킴성태 젠지 vs TS 세계대회 #VCTWATCHPARTY
# 다쁘 안녕하세요 오랜만이네요..ㅎㅅㅎ
# 수니그룹 배그나 서우연 슈퍼카 사러 갑니다
# [kt파트너] LCK KT vs GEN 난 오늘도 응원을 한다. 포기하지않는다 #LckWatchParty
# 김된모xXIESTA VCT GEN vs TS / T1 vs TLN / #VCTWATCHPARTY
# 깨모다 ( 나는 채무다 ) 60만개 노방종 미션재료 사러가기 with 냥수디집사님
# GEN vs TS - VCT 퍼시픽 - 스테이지 2 - 그룹 스테이지 - 10일차
# 코생문 두아온 10일차 사장보이즈 데뷔 못하면 해체합니다
# [츠캄몬스타즈🌟] 안녕하세용 막내와써요
# 핫픽스완료 황밸의 지배자 등장 시즌 15 챌달리기.
# 조경훈X규빈아X가습기 소고기먹방 #감컴
# [두아온] 완까지 두걸음
# [팀진우] 영화제 시작 팀원들 연기력 검증갑니다
# [씨나인] 불만 있으신분들 들어오세요 쪽지공개 갑니다
